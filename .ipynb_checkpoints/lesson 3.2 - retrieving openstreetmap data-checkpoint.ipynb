# %%
import osmnx as ox

import matplotlib.pyplot as plt
place_name = "Kamppi, Helsinki, Finland"
graph = ox.graph_from_place(place_name)
type(graph)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
fig, ax = ox.plot_graph(graph)
plt.tight_layout()

# %%
ox.__version__
# Out:
# '0.10'

# %%
area = ox.gdf_from_place(place_name)
# buildings = ox.buildings_from_place(place_name)
buildings = ox.footprints.footprints_from_place(place_name)

print(type(area))
print(type(buildings))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
nodes, edges = ox.graph_to_gdfs(graph)
nodes.head()
# Out:
#                    highway       osmid  ref          x          y  \
# 3216400385  turning_circle  3216400385  NaN  24.934005  60.167552
# 1372233731        crossing  1372233731  NaN  24.929274  60.162290
# 319885318              NaN   319885318  NaN  24.925487  60.165072
# 1005744134             NaN  1005744134  NaN  24.924423  60.161622
# 3216400394             NaN  3216400394  NaN  24.933920  60.167662
#
#                                  geometry
# 3216400385  POINT (24.9340047 60.1675525)
# 1372233731  POINT (24.9292737 60.1622904)
# 319885318    POINT (24.925487 60.1650716)
# 1005744134   POINT (24.9244231 60.161622)
# 3216400394  POINT (24.9339199 60.1676616)

# %%
edges.head()
# Out:
#   access bridge                                           geometry  \
# 0    NaN    NaN  LINESTRING (24.9340047 60.1675525, 24.9339332 ...
# 1    NaN    NaN  LINESTRING (24.9292737 60.1622904, 24.9291717 ...
# 2    NaN    NaN  LINESTRING (24.9292737 60.1622904, 24.9292977 ...
# 3    NaN    NaN  LINESTRING (24.9292737 60.1622904, 24.929411 6...
# 4    NaN    NaN  LINESTRING (24.9292737 60.1622904, 24.9293795 ...
#
#         highway junction  key lanes  length maxspeed             name  oneway  \
# 0   residential      NaN    0   NaN  13.177       30   Kansakoulukuja   False
# 1       footway      NaN    0   NaN   6.925      NaN              NaN   False
# 2  primary_link      NaN    0     2  33.874       40              NaN    True
# 3       footway      NaN    0   NaN  12.489      NaN              NaN   False
# 4       primary      NaN    0     2  38.768       40  Hietalahdenkatu    True
#
#                    osmid  ref service tunnel           u           v
# 0               15240373  NaN     NaN    NaN  3216400385   301360890
# 1               86533507  NaN     NaN    NaN  1372233731   298367080
# 2               15103120  NaN     NaN    NaN  1372233731   292859610
# 3  [154412960, 86533507]  NaN     NaN    NaN  1372233731  4430643601
# 4               86533509  NaN     NaN    NaN  1372233731   311043714

# %%
# plt.figure(figsize=(4,8))
fig, ax = plt.subplots(figsize=(8,8),dpi=100)
area.plot(ax=ax, facecolor='black')
edges.plot(ax=ax, linewidth=1, edgecolor='#BC8F8F')
buildings.plot(ax=ax, facecolor='khaki', alpha=0.7)
plt.tight_layout()
